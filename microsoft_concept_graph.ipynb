# %%
import pandas as pd

# %%
df=pd.read_csv('/Users/akshit.jain/Downloads/microsoft_concept_graph/data-concept/data-concept-instance-relations.txt', sep='\t', names=['obj','sub', 'rel'])

# %%
df[df['sub']=='steel']
# Out:
#                                                         obj    sub   rel
# 83                                                 material  steel  4561
# 335                                                   metal  steel  2271
# 612                                                industry  steel  1613
# 4466                                                 sector  steel   467
# 6737                                           raw material  steel   346
# 8422                                      building material  steel   294
# 9739                                                product  steel   264
# 10543                                 construction material  steel   249
# 11615                             energy intensive industry  steel   232
# 12931                                             commodity  steel   214
# 13354                                        heavy industry  steel   209
# 16916                                                  item  steel   174
# ...

# %%
df[df['obj']=='metal']
# Out:
#             obj                                    sub    rel
# 7         metal                                 copper  11142
# 31        metal                               aluminum   6433
# 65        metal                                   iron   5124
# 82        metal                                 nickel   4564
# 94        metal                                   zinc   4313
# 102       metal                                   lead   4184
# 111       metal                                   gold   4058
# 116       metal                                 silver   3989
# 245       metal                               titanium   2690
# 281       metal                                cadmium   2491
# 289       metal                        stainless steel   2458
# 301       metal                               chromium   2429
# 335       metal                                  steel   2271
# 442       metal                                mercury   1928
# ...
