# %%
import os
os.chdir('/Users/akshit.jain/repos/commoncrawl/')

# %%
import pandas as pd
from spacy import displacy
import spacy

# %%
ar=pd.read_pickle('output/parsed_pages.pk')
ar=ar.meta

# %%
# start_iter=0
for doc, meta in TRAIN_DATA[start_iter:start_iter+10]:
    start_iter+=10
    doc_parsed=nlp(doc)
    displacy.render(doc_parsed, style='ent', jupyter=True)
    for (start, end, label) in meta['entities']:
        print('expected: {}'.format(doc[start:end]))

# %%
nlp = spacy.load('en_core_web_md')

# %%
doc=ar.sample(n=1).any().story
doc_parsed=nlp(doc)
displacy.render(doc_parsed, style='dep', jupyter=True)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="113450" height="2149.5" style="max-width: none; height: 2149.5px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2059.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">
# 	</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2059.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">Actress-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2059.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">author</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# ...
